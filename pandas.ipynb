# %%
# pandas
import pandas as pd
import numpy as np

# %%
s = pd.Series([1, 3, 6, np.nan, 44, 1])
s
# Out:
# 0     1.0
# 1     3.0
# 2     6.0
# 3     NaN
# 4    44.0
# 5     1.0
# dtype: float64

# %%
dates = pd.date_range('20160101',periods = 6)
dates
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index = dates, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#                    a         b         c         d
# 2016-01-01 -2.737228  1.377820  0.389566 -0.957454
# 2016-01-02  0.060941 -0.500176  0.773997 -0.610487
# 2016-01-03 -0.252026 -0.550247 -0.044781 -0.231454
# 2016-01-04 -0.607780 -0.131199 -0.102006  0.442632
# 2016-01-05 -0.674179 -0.237254 -0.267864  0.748221
# 2016-01-06  0.689354  0.662746  0.862138  0.771825

# %%
df2 = pd.DataFrame({'A':1.,'B':pd.Timestamp('20130102'),'C':pd.Series(1, index=list(range(4)),dtype = 'float32'),'D':np.array([3]*4, dtype= 'int32'),
                    'E':pd.Categorical(['test','train','test','train']),'F':'foo'})  #使用字典创建DataFrame
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df2.describe()
# Out:
#          A                    B    C    D
# count  4.0                    4  4.0  4.0
# mean   1.0  2013-01-02 00:00:00  1.0  3.0
# min    1.0  2013-01-02 00:00:00  1.0  3.0
# 25%    1.0  2013-01-02 00:00:00  1.0  3.0
# 50%    1.0  2013-01-02 00:00:00  1.0  3.0
# 75%    1.0  2013-01-02 00:00:00  1.0  3.0
# max    1.0  2013-01-02 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
df2.T
# Out:
#                      0                    1                    2  \
# A                  1.0                  1.0                  1.0
# B  2013-01-02 00:00:00  2013-01-02 00:00:00  2013-01-02 00:00:00
# C                  1.0                  1.0                  1.0
# D                    3                    3                    3
# E                 test                train                 test
# F                  foo                  foo                  foo
#
#                      3
# A                  1.0
# B  2013-01-02 00:00:00
# C                  1.0
# D                    3
# E                train
# F                  foo

# %%
df2.sort_index(axis = 1, ascending = False)  # 对列标签排序
# Out:
#      F      E  D    C          B    A
# 0  foo   test  3  1.0 2013-01-02  1.0
# 1  foo  train  3  1.0 2013-01-02  1.0
# 2  foo   test  3  1.0 2013-01-02  1.0
# 3  foo  train  3  1.0 2013-01-02  1.0

# %%
df2.sort_index(axis = 0, ascending = False)  # 对行标签排序
# Out:
#      A          B    C  D      E    F
# 3  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 0  1.0 2013-01-02  1.0  3   test  foo

# %%
df2.sort_values(by = 'E') # 对数值排序
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
